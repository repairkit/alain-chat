# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_unstructured.document_loaders import UnstructuredLoader
from langchain_community.vectorstores.utils import filter_complex_metadata

file_path = "alain_propos_bonheur.doc"
loader = UnstructuredLoader(
    file_path=file_path,
)
# ベクトルデータベースが対応していないメタデータの削除
documents = filter_complex_metadata(loader.load())

def analysis_langchain_documents(documents, break_point=10):
    num_documents = len(documents)
    lengths = [len(doc.page_content) for doc in documents]
    total_length = sum(lengths)

    print(f"Number of documents: {num_documents}")
    print(f"Total length of text: {total_length} characters")
    print(f'Individual document lengths: {lengths[:10]} {"" if len(lengths) <= 10 else "..."}')

    for i, doc in enumerate(documents):
        print("="*10)
        print(f"Document {i+1} (Length: {len(doc.page_content)}): {doc.page_content[:100]}...")
        print("="*10+"\n\n")
        if i >= break_point:
            break

analysis_langchain_documents(documents, break_point=1000)
# Out:
# INFO: convert /home/syun2/project/alain-chat/alain_propos_bonheur.doc as a Writer document -> /tmp/tmpiv38oznv/alain_propos_bonheur.docx using filter : MS Word 2007 XML
# Number of documents: 1029
# Total length of text: 318831 characters
# Individual document lengths: [39, 523, 142, 34, 28, 150, 32, 32, 37, 49] ...
# ==========
# Document 1 (Length: 39): Alain, Propos sur le bonheur (1928)	199...
# ==========
#
#
# ==========
# Document 2 (Length: 523): Alain (Émile Chartier) (1868-1951) Propos sur le bonheur Un document produit en version numérique pa...
# ==========
#
#
# ==========
# Document 3 (Length: 142): Cette édition électronique a été réalisée par Robert Caron, bénévole, professeur de lettres à la ret...
# ==========
#
#
# ==========
# Document 4 (Length: 34): Alain (Émile Chartier) (1868-1951)...
# ==========
#
#
# ==========
# Document 5 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 6 (Length: 150): Une édition électronique réalisée à partir du livre d’Alain, PROPOS SUR LE BONHEUR. Paris : Éditions...
# ==========
#
#
# ==========
# Document 7 (Length: 32): Polices de caractères utilisée :...
# ==========
#
#
# ==========
# Document 8 (Length: 32): Pour le texte: Times, 12 points....
# ==========
#
#
# ==========
# Document 9 (Length: 37): Pour les citations : Times 10 points....
# ==========
#
#
# ==========
# Document 10 (Length: 49): Pour les notes de bas de page : Times, 10 points....
# ==========
#
#
# ==========
# Document 11 (Length: 94): Édition électronique réalisée avec le traitement de textes Microsoft Word 2001 pour Macintosh....
# ==========
#
#
# ==========
# Document 12 (Length: 30): Mise en page sur papier format...
# ==========
#
#
# ==========
# Document 13 (Length: 33): LETTRE (US letter), 8.5’’ x 11’’)...
# ==========
#
#
# ==========
# Document 14 (Length: 56): Édition complétée le 30 juin  200 3à Chicoutimi, Québec....
# ==========
#
#
# ==========
# Document 15 (Length: 18): Table des matières...
# ==========
#
#
# ==========
# Document 16 (Length: 7): Préface...
# ==========
#
#
# ==========
# Document 17 (Length: 29): Dédicace à Mme Morre-Lambelin...
# ==========
#
#
# ==========
# Document 18 (Length: 29): I.	Bucéphale, 8 décembre 1922...
# ==========
#
#
# ==========
# Document 19 (Length: 31): II.	Irritation, 5 décembre 1912...
# ==========
#
#
# ==========
# Document 20 (Length: 31): III.	Marie triste, 18 août 1913...
# ==========
#
#
# ==========
# Document 21 (Length: 33): IV.	Neurasthénie, 22 février 1908...
# ==========
#
#
# ==========
# Document 22 (Length: 29): V.	Mélancolie, 6 février 1911...
# ==========
#
#
# ==========
# Document 23 (Length: 28): VI.	Des passions, 9 mai 1911...
# ==========
#
#
# ==========
# Document 24 (Length: 37): VII.	Crainte est maladie, 5 mars 1922...
# ==========
#
#
# ==========
# Document 25 (Length: 39): VIII.	De l'imagination, 20 février 1923...
# ==========
#
#
# ==========
# Document 26 (Length: 35): IX.	Maux d'esprit, 12 décembre 1910...
# ==========
#
#
# ==========
# Document 27 (Length: 27): X.	Argan, 11 septembre 1923...
# ==========
#
#
# ==========
# Document 28 (Length: 26): XI.	Médecine, 23 mars 1922...
# ==========
#
#
# ==========
# Document 29 (Length: 30): XII.	Le sourire, 20 avril 1923...
# ==========
#
#
# ==========
# Document 30 (Length: 29): XIII.	Accidents, 22 août 1923...
# ==========
#
#
# ==========
# Document 31 (Length: 26): XIV.	Drames, 24 avril 1912...
# ==========
#
#
# ==========
# Document 32 (Length: 29): XV.	Sur la mort, 10 août 1923...
# ==========
#
#
# ==========
# Document 33 (Length: 31): XVI.	Attitudes, 16 février 1922...
# ==========
#
#
# ==========
# Document 34 (Length: 31): XVII.	Gymnastique, 16 mars 1922...
# ==========
#
#
# ==========
# Document 35 (Length: 32): XVIII.	Prières, 24 décembre 1913...
# ==========
#
#
# ==========
# Document 36 (Length: 36): XIX.	L'art de bâiller, 24 avril 1923...
# ==========
#
#
# ==========
# Document 37 (Length: 28): XX.	Humeur, 21 décembre 1921...
# ==========
#
#
# ==========
# Document 38 (Length: 36): XXI.	Des caractères, 4 décembre 1923...
# ==========
#
#
# ==========
# Document 39 (Length: 35): XXII.	La fatalité, 12 décembre 1922...
# ==========
#
#
# ==========
# Document 40 (Length: 38): XXIII.	L'âme prophétique, 25 août 1913...
# ==========
#
#
# ==========
# Document 41 (Length: 32): XXIV.	Notre avenir, 28 août 1911...
# ==========
#
#
# ==========
# Document 42 (Length: 31): XXV.	Prédictions, 14 avril 1908...
# ==========
#
#
# ==========
# Document 43 (Length: 30): XXVI.	Hercule, 7 novembre 1922...
# ==========
#
#
# ==========
# Document 44 (Length: 26): XXVII.	Vouloir, 9 mai 1909...
# ==========
#
#
# ==========
# Document 45 (Length: 49): XXVIII.	Chacun a ce qu'il veut, 21 septembre 1924...
# ==========
#
#
# ==========
# Document 46 (Length: 36): XXIX.	De la destinée, 3 octobre 1923...
# ==========
#
#
# ==========
# Document 47 (Length: 36): XXX.	Ne pas désespérer, 24 août 1912...
# ==========
#
#
# ==========
# Document 48 (Length: 41): XXXI.	Dans la grande prairie, 5 juin 1909...
# ==========
#
#
# ==========
# Document 49 (Length: 46): XXXII.	Passions de voisinage, 27 décembre 1910...
# ==========
#
#
# ==========
# Document 50 (Length: 35): XXXIII.	En famille, 12 juillet 1907...
# ==========
#
#
# ==========
# Document 51 (Length: 31): XXXIV.	Sollicitude, 30 mai 1907...
# ==========
#
#
# ==========
# Document 52 (Length: 40): XXXV.	La paix du ménage, 14 octobre 1913...
# ==========
#
#
# ==========
# Document 53 (Length: 42): XXXVI.	De la vie privée, 10 septembre 1913...
# ==========
#
#
# ==========
# Document 54 (Length: 35): XXXVII.	Le couple, 14 décembre 1912...
# ==========
#
#
# ==========
# Document 55 (Length: 33): XXXVIII.	L'ennui, 29 janvier 1909...
# ==========
#
#
# ==========
# Document 56 (Length: 30): XXXIX.	Vitesse, 2 juillet 1908...
# ==========
#
#
# ==========
# Document 57 (Length: 29): XL.	Le jeu, 1er novembre 1913...
# ==========
#
#
# ==========
# Document 58 (Length: 30): XLI.	Espérance, 3 octobre 1921...
# ==========
#
#
# ==========
# Document 59 (Length: 24): XLII.	Agir, 3 avril 1911...
# ==========
#
#
# ==========
# Document 60 (Length: 39): XLIII.	Hommes d'action, 21 février 1910...
# ==========
#
#
# ==========
# Document 61 (Length: 31): XLIV.	Diogène, 30 novembre 1922...
# ==========
#
#
# ==========
# Document 62 (Length: 30): XLV.	L'égoïste, 5 février 1913...
# ==========
#
#
# ==========
# Document 63 (Length: 38): XLVI.	Le roi s'ennuie, 22 janvier 1908...
# ==========
#
#
# ==========
# Document 64 (Length: 34): XLVII.	Aristote, 15 septembre 1924...
# ==========
#
#
# ==========
# Document 65 (Length: 42): XLVIII.	Heureux agriculteurs, 28 août 1922...
# ==========
#
#
# ==========
# Document 66 (Length: 30): XLIX.	Travaux, 6 novembre 1911...
# ==========
#
#
# ==========
# Document 67 (Length: 28): L.	Oeuvres, 29 novembre 1922...
# ==========
#
#
# ==========
# Document 68 (Length: 32): LI.	Regarde au loin, 15 mai 1911...
# ==========
#
#
# ==========
# Document 69 (Length: 26): LII.	Voyages, 29 août 1906...
# ==========
#
#
# ==========
# Document 70 (Length: 43): LIII.	La danse des poignards, 17 avril 1908...
# ==========
#
#
# ==========
# Document 71 (Length: 36): LIV.	Déclamations, 29 septembre 1911...
# ==========
#
#
# ==========
# Document 72 (Length: 29): LV	Jérémiades, 4 janvier 1912...
# ==========
#
#
# ==========
# Document 73 (Length: 42): LVI.	L'éloquence des passions, 14 mai 1913...
# ==========
#
#
# ==========
# Document 74 (Length: 35): LVII.	Du désespoir, 31 octobre 1911...
# ==========
#
#
# ==========
# Document 75 (Length: 34): LVIII.	De la pitié, 5 octobre 1909...
# ==========
#
#
# ==========
# Document 76 (Length: 36): LIX.	Les maux d'autrui, 23 mars 1910...
# ==========
#
#
# ==========
# Document 77 (Length: 33): LX.	Consolation, 26 novembre 1910...
# ==========
#
#
# ==========
# Document 78 (Length: 40): LXI.	Le culte des morts, 8 novembre 1907...
# ==========
#
#
# ==========
# Document 79 (Length: 34): LXII.	Gribouille, 31 décembre 1911...
# ==========
#
#
# ==========
# Document 80 (Length: 37): LXIII.	Sous la pluie, 4 novembre 1907...
# ==========
#
#
# ==========
# Document 81 (Length: 31): LXIV.	Effervescence, 3 mai 1913...
# ==========
#
#
# ==========
# Document 82 (Length: 31): LXV.	Épictète, 10 décembre 1910...
# ==========
#
#
# ==========
# Document 83 (Length: 29): LXVI.	Stoïcisme, 31 août 1913...
# ==========
#
#
# ==========
# Document 84 (Length: 35): LXVII.	Connais-toi, 23 octobre 1909...
# ==========
#
#
# ==========
# Document 85 (Length: 34): LXVIII.	Optimisme, 28 janvier 1913...
# ==========
#
#
# ==========
# Document 86 (Length: 31): LXIX.	Dénouer, 27 décembre 1921...
# ==========
#
#
# ==========
# Document 87 (Length: 31): LXX.	Patience, 11 décembre 1910...
# ==========
#
#
# ==========
# Document 88 (Length: 33): LXXI.	Bienveillance, 8 avril 1922...
# ==========
#
#
# ==========
# Document 89 (Length: 32): LXXII.	Injures, 17 novembre 1913...
# ==========
#
#
# ==========
# Document 90 (Length: 37): LXXIII.	Bonne humeur, 10 octobre 1909...
# ==========
#
#
# ==========
# Document 91 (Length: 34): LXXIV.	Une cure, 24 septembre 1911...
# ==========
#
#
# ==========
# Document 92 (Length: 41): LXXV.	Hygiène de l'esprit, 9 octobre 1909...
# ==========
#
#
# ==========
# Document 93 (Length: 39): LXXVI.	L'hymne au lait, 21 janvier 1924...
# ==========
#
#
# ==========
# Document 94 (Length: 32): LXXVII.	Amitié, 27 décembre 1907...
# ==========
#
#
# ==========
# Document 95 (Length: 40): LXXVIII.	De l'irrésolution, 10 août 1924...
# ==========
#
#
# ==========
# Document 96 (Length: 36): LXXIX.	Cérémonies, 26 septembre 1923...
# ==========
#
#
# ==========
# Document 97 (Length: 33): LXXX.	Bonne année, 2 janvier 1910...
# ==========
#
#
# ==========
# Document 98 (Length: 29): LXXXI.	Vœux, 20 décembre 1926...
# ==========
#
#
# ==========
# Document 99 (Length: 36): LXXXII.	La politesse, 6 janvier 1922...
# ==========
#
#
# ==========
# Document 100 (Length: 35): LXXXIII.	Savoir-vivre, 21 mars 1911...
# ==========
#
#
# ==========
# Document 101 (Length: 34): LXXXIV.	Faire plaisir, 8 mars 1911...
# ==========
#
#
# ==========
# Document 102 (Length: 37): LXXXV.	Platon médecin, 4 février 1922...
# ==========
#
#
# ==========
# Document 103 (Length: 50): LXXXVI.	L'art de se bien porter, 28 septembre 1921...
# ==========
#
#
# ==========
# Document 104 (Length: 32): LXXXVII.	Victoires, 18 mars 1911...
# ==========
#
#
# ==========
# Document 105 (Length: 35): LXXXVIII.	Poètes, 12 septembre 1923...
# ==========
#
#
# ==========
# Document 106 (Length: 42): LXXXIX.	Bonheur est vertu, 5 novembre 1922...
# ==========
#
#
# ==========
# Document 107 (Length: 46): XC.	Que le bonheur est généreux, 10 avril 1923...
# ==========
#
#
# ==========
# Document 108 (Length: 43): XCI.	L'art d'être heureux, 8 septembre 1910...
# ==========
#
#
# ==========
# Document 109 (Length: 44): XCII.	Du devoir d'être heureux, 16 mars 1923...
# ==========
#
#
# ==========
# Document 110 (Length: 39): XCIII.	Il faut jurer, 29 septembre 1923...
# ==========
#
#
# ==========
# Document 111 (Length: 22): Alain (Émile Chartier)...
# ==========
#
#
# ==========
# Document 112 (Length: 11): (1868-1951)...
# ==========
#
#
# ==========
# Document 113 (Length: 22): PROPOS SUR LE BONHEUR....
# ==========
#
#
# ==========
# Document 114 (Length: 66): Paris : Éditions Gallimard, 1928, 218 pp.
# Collection folio-essais....
# ==========
#
#
# ==========
# Document 115 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 116 (Length: 712): Alain Propos sur le bonheur (1928) Voici le jardin du philosophe. On y cueillera des fruits mûris su...
# ==========
#
#
# ==========
# Document 117 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 118 (Length: 7): Préface...
# ==========
#
#
# ==========
# Document 119 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 120 (Length: 2851): Émile Chartier, dit Alain (1868-1951), est né dans la petite ville de Mortagne-au-Perche, qui lui co...
# ==========
#
#
# ==========
# Document 121 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 122 (Length: 8): Dédicace...
# ==========
#
#
# ==========
# Document 123 (Length: 20): à Mme Morre-Lambelin...
# ==========
#
#
# ==========
# Document 124 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 125 (Length: 2111): Ce recueil  me plaît. La doctrine me paraît sans reproche, quoique le problème soit divisé en petits...
# ==========
#
#
# ==========
# Document 126 (Length: 15): Le 1er mai 1925...
# ==========
#
#
# ==========
# Document 127 (Length: 6): 	ALAIN...
# ==========
#
#
# ==========
# Document 128 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 129 (Length: 1): I...
# ==========
#
#
# ==========
# Document 130 (Length: 9): Bucéphale...
# ==========
#
#
# ==========
# Document 131 (Length: 15): 8 décembre 1922...
# ==========
#
#
# ==========
# Document 132 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 133 (Length: 373): Lorsqu'un petit enfant crie et ne veut pas être consolé, la nourrice fait souvent les plus ingénieus...
# ==========
#
#
# ==========
# Document 134 (Length: 677): Lorsque Bucéphale, cheval illustre, fut présenté au jeune Alexandre, aucun écuyer ne pouvait se main...
# ==========
#
#
# ==========
# Document 135 (Length: 817): Bien des hommes ont réfuté la peur, et par fortes raisons ; mais celui qui a peur n'écoute point les...
# ==========
#
#
# ==========
# Document 136 (Length: 1281): L'impatience d'un homme et son humeur viennent quelquefois de ce qu'il est resté trop longtemps debo...
# ==========
#
#
# ==========
# Document 137 (Length: 15): 8 décembre 1922...
# ==========
#
#
# ==========
# Document 138 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 139 (Length: 2): II...
# ==========
#
#
# ==========
# Document 140 (Length: 10): Irritation...
# ==========
#
#
# ==========
# Document 141 (Length: 15): 5 décembre 1912...
# ==========
#
#
# ==========
# Document 142 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 143 (Length: 1410): Quand on avale de travers, il se produit un grand tumulte dans le corps, comme si un danger imminent...
# ==========
#
#
# ==========
# Document 144 (Length: 846): Pour la toux, dans le rhume, il existe une discipline du même genre, trop peu pratiquée. La plupart ...
# ==========
#
#
# ==========
# Document 145 (Length: 1095): Ce mot, irritation, doit faire réfléchir. Par la sagesse du langage, il convient aussi pour désigner...
# ==========
#
#
# ==========
# Document 146 (Length: 15): 5 décembre 1912...
# ==========
#
#
# ==========
# Document 147 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 148 (Length: 3): III...
# ==========
#
#
# ==========
# Document 149 (Length: 12): Marie triste...
# ==========
#
#
# ==========
# Document 150 (Length: 12): 18 août 1913...
# ==========
#
#
# ==========
# Document 151 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 152 (Length: 1002): Il n'est pas inutile de réfléchir sur les folies circulaires, et notamment sur cette « Marie triste ...
# ==========
#
#
# ==========
# Document 153 (Length: 848): Mais après une semaine tout changeait de ton. Elle tombait à une langueur désespérée ; rien ne l'int...
# ==========
#
#
# ==========
# Document 154 (Length: 697): Mais le professeur de psychologie allait découvrir une leçon plus rude encore, une plus redoutable é...
# ==========
#
#
# ==========
# Document 155 (Length: 542): Un ami, qui veut se croire triste dans le fond, me disait là-dessus : « Quoi de plus clair ? Nous n'...
# ==========
#
#
# ==========
# Document 156 (Length: 704): Ce n'est pas si simple. Il est clair qu'à remâcher des jugements sévères, des prédictions sinistres,...
# ==========
#
#
# ==========
# Document 157 (Length: 12): 18 août 1913...
# ==========
#
#
# ==========
# Document 158 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 159 (Length: 2): IV...
# ==========
#
#
# ==========
# Document 160 (Length: 12): Neurasthénie...
# ==========
#
#
# ==========
# Document 161 (Length: 15): 22 février 1908...
# ==========
#
#
# ==========
# Document 162 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 163 (Length: 788): Par ces temps de giboulées, l'humeur des hommes, et celle des femmes aussi, change comme le ciel. Un...
# ==========
#
#
# ==========
# Document 164 (Length: 393): Laissez, lui dis-je, les grands mots et essayez de comprendre les choses. Votre état est celui de to...
# ==========
#
#
# ==========
# Document 165 (Length: 1272): En réalité, les motifs qu'on a d'être heureux ou malheureux sont sans poids ; tout dépend de notre c...
# ==========
#
#
# ==========
# Document 166 (Length: 830): Spinoza dit qu'il ne se peut pas que l'homme n'ait pas de passions, mais que le sage forme en son âm...
# ==========
#
#
# ==========
# Document 167 (Length: 15): 22 février 1908...
# ==========
#
#
# ==========
# Document 168 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 169 (Length: 1): V...
# ==========
#
#
# ==========
# Document 170 (Length: 10): Mélancolie...
# ==========
#
#
# ==========
# Document 171 (Length: 14): 6 février 1911...
# ==========
#
#
# ==========
# Document 172 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 173 (Length: 607): Il y a quelque temps, je voyais un ami qui souffrait d'un caillou dans le rein, et qui était d'humeu...
# ==========
#
#
# ==========
# Document 174 (Length: 665): La profonde tristesse résulte toujours d'un état maladif du corps ; tant qu'un chagrin n'est pas mal...
# ==========
#
#
# ==========
# Document 175 (Length: 986): Considérons pourtant les malades que l'on appelle mélancoliques ; nous verrons qu'ils savent trouver...
# ==========
#
#
# ==========
# Document 176 (Length: 1052): De cette espèce de folie, qui porte les passions jusqu'à la rage, on peut se délivrer en se disant, ...
# ==========
#
#
# ==========
# Document 177 (Length: 14): 6 février 1911...
# ==========
#
#
# ==========
# Document 178 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 179 (Length: 2): VI...
# ==========
#
#
# ==========
# Document 180 (Length: 12): Des passions...
# ==========
#
#
# ==========
# Document 181 (Length: 10): 9 mai 1911...
# ==========
#
#
# ==========
# Document 182 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 183 (Length: 1760): On supporte moins aisément la passion que la maladie ; dont la cause est sans doute en ceci, que not...
# ==========
#
#
# ==========
# Document 184 (Length: 941): Il y a toujours du remords et de l'épouvante dans la passion, et par raison, il me semble ; car on s...
# ==========
#
#
# ==========
# Document 185 (Length: 1281): Beaucoup ont écrit là-dessus ; et les stoïciens nous ont laissé de beaux raisonnements contre la cra...
# ==========
#
#
# ==========
# Document 186 (Length: 10): 9 mai 1911...
# ==========
#
#
# ==========
# Document 187 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 188 (Length: 3): VII...
# ==========
#
#
# ==========
# Document 189 (Length: 19): Crainte est maladie...
# ==========
#
#
# ==========
# Document 190 (Length: 11): 5 mars 1922...
# ==========
#
#
# ==========
# Document 191 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 192 (Length: 1268): Je me souviens d'un canonnier qui lisait dans les mains. Il était bûcheron de son métier et formé pa...
# ==========
#
#
# ==========
# Document 193 (Length: 854): Thalès, Bias, Démocrite et les autres vieillards fameux des temps anciens avaient sans doute une ten...
# ==========
#
#
# ==========
# Document 194 (Length: 1225): Le vertige qui nous prend sur les hauteurs est une maladie véritable, qui vient de ce que nous mimon...
# ==========
#
#
# ==========
# Document 195 (Length: 11): 5 mars 1922...
# ==========
#
#
# ==========
# Document 196 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 197 (Length: 4): VIII...
# ==========
#
#
# ==========
# Document 198 (Length: 16): De l'imagination...
# ==========
#
#
# ==========
# Document 199 (Length: 15): 20 février 1923...
# ==========
#
#
# ==========
# Document 200 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 201 (Length: 492): Lorsque le médecin vous recoud la peau du visage, à la suite de quelque petit accident, il y a, parm...
# ==========
#
#
# ==========
# Document 202 (Length: 632): Cet exemple est bon à considérer parce qu'il fait voir un genre de pitié qui ne dépend point de nos ...
# ==========
#
#
# ==========
# Document 203 (Length: 1006): D'où je comprends que nos semblables ont grande puissance sur nous, par leur présence seule, par les...
# ==========
#
#
# ==========
# Document 204 (Length: 1069): On pourrait bien aussi expliquer le vertige par un raisonnement ; l'homme devant le gouffre se dirai...
# ==========
#
#
# ==========
# Document 205 (Length: 15): 20 février 1923...
# ==========
#
#
# ==========
# Document 206 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 207 (Length: 2): IX...
# ==========
#
#
# ==========
# Document 208 (Length: 13): Maux d'esprit...
# ==========
#
#
# ==========
# Document 209 (Length: 16): 12 décembre 1910...
# ==========
#
#
# ==========
# Document 210 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 211 (Length: 470): L'imagination est pire qu'un bourreau chinois ; elle dose la peur ; elle nous la fait goûter en gour...
# ==========
#
#
# ==========
# Document 212 (Length: 1079): Aussi, moi qui pense à l'accident, j'en juge très mal. J'en juge comme un homme qui, toujours sur le...
# ==========
#
#
# ==========
# Document 213 (Length: 538): Les maux réels vont vite, comme le bourreau va chez nous. Il coupe les cheveux, échancre la chemise,...
# ==========
#
#
# ==========
# Document 214 (Length: 625): On souffre de retrouver un vieillard revenu à l'enfance, ou un ivrogne hébété qui nous montre « le t...
# ==========
#
#
# ==========
# Document 215 (Length: 422): C'est pourquoi il n'y a que les vivants qui soient atteints par la mort, que les heureux qui conçoiv...
# ==========
#
#
# ==========
# Document 216 (Length: 16): 12 décembre 1910...
# ==========
#
#
# ==========
# Document 217 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 218 (Length: 1): X...
# ==========
#
#
# ==========
# Document 219 (Length: 5): Argan...
# ==========
#
#
# ==========
# Document 220 (Length: 17): 11 septembre 1923...
# ==========
#
#
# ==========
# Document 221 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 222 (Length: 871): De très petites causes peuvent gâter une belle journée, par exemple un soulier qui blesse. Rien ne p...
# ==========
#
#
# ==========
# Document 223 (Length: 1778): On dit souvent que la mauvaise humeur est une maladie et qu'on n'y peut rien. C'est pourquoi je rapp...
# ==========
#
#
# ==========
# Document 224 (Length: 783): Un sourire nous semble peu de chose et sans effet sur l'humeur ; aussi ne l'essayons-nous point. Mai...
# ==========
#
#
# ==========
# Document 225 (Length: 17): 11 septembre 1923...
# ==========
#
#
# ==========
# Document 226 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 227 (Length: 2): XI...
# ==========
#
#
# ==========
# Document 228 (Length: 8): Médecine...
# ==========
#
#
# ==========
# Document 229 (Length: 12): 23 mars 1922...
# ==========
#
#
# ==========
# Document 230 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 231 (Length: 903): « Je connais, dit l'homme de science, un nombre important de vérités, et je forme une idée suffisant...
# ==========
#
#
# ==========
# Document 232 (Length: 2278): « Je connais, dit le liseur, un nombre important d'idées fausses qui compliquèrent la vie des hommes...
# ==========
#
#
# ==========
# Document 233 (Length: 12): 23 mars 1922...
# ==========
#
#
# ==========
# Document 234 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 235 (Length: 3): XII...
# ==========
#
#
# ==========
# Document 236 (Length: 10): Le sourire...
# ==========
#
#
# ==========
# Document 237 (Length: 13): 20 avril 1923...
# ==========
#
#
# ==========
# Document 238 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 239 (Length: 1715): Je voudrais dire de la mauvaise humeur qu'elle n'est pas moins cause qu'effet ; je serais même porté...
# ==========
#
#
# ==========
# Document 240 (Length: 752): Passe encore pour les passions ; ne s'en délivre pas qui veut ; on n'y peut arriver que par un long ...
# ==========
#
#
# ==========
# Document 241 (Length: 930): Réagir contre l'humeur ce n'est point l'affaire du jugement ; il n'y peut rien ; mais il faut change...
# ==========
#
#
# ==========
# Document 242 (Length: 13): 20 avril 1923...
# ==========
#
#
# ==========
# Document 243 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 244 (Length: 4): XIII...
# ==========
#
#
# ==========
# Document 245 (Length: 9): Accidents...
# ==========
#
#
# ==========
# Document 246 (Length: 12): 22 août 1923...
# ==========
#
#
# ==========
# Document 247 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 248 (Length: 1338): Chacun a médité un petit moment sur l'effroyable chute. L'énorme voiture a manqué d'une roue et s'es...
# ==========
#
#
# ==========
# Document 249 (Length: 913): Ces remarques, qui sont le thème de toute consolation véritable, sont fondées sur une exacte analyse...
# ==========
#
#
# ==========
# Document 250 (Length: 1341): Le soir que je partis pour la guerre, dans ce triste wagon plein de rumeurs, de récits passionnés et...
# ==========
#
#
# ==========
# Document 251 (Length: 12): 22 août 1923...
# ==========
#
#
# ==========
# Document 252 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 253 (Length: 3): XIV...
# ==========
#
#
# ==========
# Document 254 (Length: 6): Drames...
# ==========
#
#
# ==========
# Document 255 (Length: 13): 24 avril 1912...
# ==========
#
#
# ==========
# Document 256 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 257 (Length: 845): Les réchappés de ce grand naufrage ont des souvenirs terrifiants. Cette muraille de glace qui se mon...
# ==========
#
#
# ==========
# Document 258 (Length: 1137): Quand le jour se lève au château, dans Macbeth, il y a un portier qui regarde le jour naissant et le...
# ==========
#
#
# ==========
# Document 259 (Length: 917): Sentir, c'est réfléchir, c'est se souvenir. Chacun a pu observer la même chose, dans les petits et g...
# ==========
#
#
# ==========
# Document 260 (Length: 371): Surtout, quels qu'aient pu être les sentiments de ceux qui sont morts, la mort a tout effacé ; avant...
# ==========
#
#
# ==========
# Document 261 (Length: 13): 24 avril 1912...
# ==========
#
#
# ==========
# Document 262 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 263 (Length: 2): XV...
# ==========
#
#
# ==========
# Document 264 (Length: 11): Sur la mort...
# ==========
#
#
# ==========
# Document 265 (Length: 12): 10 août 1923...
# ==========
#
#
# ==========
# Document 266 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 267 (Length: 1106): La mort d'un homme d’État est une occasion de méditer ; et l'on voit partout des théologiens d'un in...
# ==========
#
#
# ==========
# Document 268 (Length: 1173): L'homme est courageux ; non pas à l'occasion, mais essentiellement. Agir c'est oser. Penser c'est os...
# ==========
#
#
# ==========
# Document 269 (Length: 1364): Voyez même un malade, comme il est aussitôt guéri, par la maladie, de la peur d'être malade. C'est l...
# ==========
#
#
# ==========
# Document 270 (Length: 12): 10 août 1923...
# ==========
#
#
# ==========
# Document 271 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 272 (Length: 3): XVI...
# ==========
#
#
# ==========
# Document 273 (Length: 9): Attitudes...
# ==========
#
#
# ==========
# Document 274 (Length: 15): 16 février 1922...
# ==========
#
#
# ==========
# Document 275 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 276 (Length: 937): Le plus vulgaire des hommes est un grand artiste dès qu'il mime ses malheurs. S'il a le cœur serré, ...
# ==========
#
#
# ==========
# Document 277 (Length: 577): Les coutumes de politesse sont bien puissantes sur nos pensées ; et ce n'est pas un petit secours co...
# ==========
#
#
# ==========
# Document 278 (Length: 559): L'attitude religieuse est utile à considérer pour le médecin ; car ce corps agenouillé, replié et dé...
# ==========
#
#
# ==========
# Document 279 (Length: 535): Il est beau de voir comment un homme chasse une idée importune ; vous le voyez hausser les épaules e...
# ==========
#
#
# ==========
# Document 280 (Length: 620): J'aime le geste de la perplexité ; l'homme se gratte les cheveux derrière l'oreille ; or, cette ruse...
# ==========
#
#
# ==========
# Document 281 (Length: 15): 16 février 1922...
# ==========
#
#
# ==========
# Document 282 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 283 (Length: 4): XVII...
# ==========
#
#
# ==========
# Document 284 (Length: 11): Gymnastique...
# ==========
#
#
# ==========
# Document 285 (Length: 12): 16 mars 1922...
# ==========
#
#
# ==========
# Document 286 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 287 (Length: 1318): Comment expliquer qu'un pianiste, qui croit mourir de peur en entrant sur la scène, soit immédiateme...
# ==========
#
#
# ==========
# Document 288 (Length: 1989): Un aviateur m'a conté quelle belle peur il eut pendant deux heures, alors qu'il était couché sur l'h...
# ==========
#
#
# ==========
# Document 289 (Length: 12): 16 mars 1922...
# ==========
#
#
# ==========
# Document 290 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 291 (Length: 5): XVIII...
# ==========
#
#
# ==========
# Document 292 (Length: 7): Prières...
# ==========
#
#
# ==========
# Document 293 (Length: 16): 24 décembre 1913...
# ==========
#
#
# ==========
# Document 294 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 295 (Length: 545): On ne peut pas du tout penser le son i en ouvrant la bouche. Essayez, et vous constaterez que votre ...
# ==========
#
#
# ==========
# Document 296 (Length: 443): Toute religion enferme une prodigieuse sagesse pratique ; par exemple, contre les mouvements de révo...
# ==========
#
#
# ==========
# Document 297 (Length: 2535): Mais les hommes, dès qu'ils sont livrés aux passions, sont d'une naïveté étonnante. Ils croiront dif...
# ==========
#
#
# ==========
# Document 298 (Length: 16): 24 décembre 1913...
# ==========
#
#
# ==========
# Document 299 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 300 (Length: 3): XIX...
# ==========
#
#
# ==========
# Document 301 (Length: 16): L'art de bâiller...
# ==========
#
#
# ==========
# Document 302 (Length: 13): 24 avril 1923...
# ==========
#
#
# ==========
# Document 303 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 304 (Length: 575): Un chien qui bâille au coin du feu, cela avertit les chasseurs de renvoyer les soucis au lendemain. ...
# ==========
#
#
# ==========
# Document 305 (Length: 1569): Tout le monde peut remarquer qu'attention et surprise coupent, comme on dit, respiration. La physiol...
# ==========
#
#
# ==========
# Document 306 (Length: 963): Le rire et les sanglots sont des solutions du même genre, mais plus retenues, plus contrariées ; il ...
# ==========
#
#
# ==========
# Document 307 (Length: 13): 24 avril 1923...
# ==========
#
#
# ==========
# Document 308 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 309 (Length: 2): XX...
# ==========
#
#
# ==========
# Document 310 (Length: 6): Humeur...
# ==========
#
#
# ==========
# Document 311 (Length: 16): 21 décembre 1921...
# ==========
#
#
# ==========
# Document 312 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 313 (Length: 1276): Selon le système de l'exaspération, rien n'est meilleur que de se gratter. C'est choisir son mal ; c...
# ==========
#
#
# ==========
# Document 314 (Length: 2086): C'est pourquoi je ne méprise pas les gens qui disent : «Voilà un froid sec ; rien n'est meilleur pou...
# ==========
#
#
# ==========
# Document 315 (Length: 16): 21 décembre 1921...
# ==========
#
#
# ==========
# Document 316 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 317 (Length: 3): XXI...
# ==========
#
#
# ==========
# Document 318 (Length: 14): Des caractères...
# ==========
#
#
# ==========
# Document 319 (Length: 15): 4 décembre 1923...
# ==========
#
#
# ==========
# Document 320 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 321 (Length: 907): Chacun a de l'humeur selon le vent et selon l'estomac. L'un donne un coup de pied dans la porte, l'a...
# ==========
#
#
# ==========
# Document 322 (Length: 663): Il arrive que l'on supporte mal les parfums ; cette humeur contre les bouquets et l'eau de Cologne n...
# ==========
#
#
# ==========
# Document 323 (Length: 720): Il y a des gens qui se mettent à croire qu'ils n'ont plus de mémoire, ou bien qu'ils ne trouvent plu...
# ==========
#
#
# ==========
# Document 324 (Length: 895): L'ingénieux système de Freud, un moment célèbre, perd déjà de son crédit par ceci, qu'il est trop fa...
# ==========
#
#
# ==========
# Document 325 (Length: 15): 4 décembre 1923...
# ==========
#
#
# ==========
# Document 326 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 327 (Length: 4): XXII...
# ==========
#
#
# ==========
# Document 328 (Length: 11): La fatalité...
# ==========
#
#
# ==========
# Document 329 (Length: 16): 12 décembre 1922...
# ==========
#
#
# ==========
# Document 330 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 331 (Length: 651): Nous ne savons rien commencer, je dis même pour allonger le bras ; nul ne commence par donner ordre ...
# ==========
#
#
# ==========
# Document 332 (Length: 1186): Qui est-ce qui a choisi ? Je le demande. Personne n'a choisi, puisque nous sommes tous d'abord des e...
# ==========
#
#
# ==========
# Document 333 (Length: 1349): « Las, que n'ai-je estudié ? » C'est l'excuse du paresseux. Étudie donc. Je ne crois pas qu'avoir ét...
# ==========
#
#
# ==========
# Document 334 (Length: 16): 12 décembre 1922...
# ==========
#
#
# ==========
# Document 335 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 336 (Length: 5): XXIII...
# ==========
#
#
# ==========
# Document 337 (Length: 17): L'âme prophétique...
# ==========
#
#
# ==========
# Document 338 (Length: 12): 25 août 1913...
# ==========
#
#
# ==========
# Document 339 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 340 (Length: 476): Un philosophe assez obscur a voulu nommer âme prophétique un certain état de passivité attentive, si...
# ==========
#
#
# ==========
# Document 341 (Length: 538): Quelquefois l'artiste voudrait retomber à cet état de donner audience à tout, à toute couleur, à tou...
# ==========
#
#
# ==========
# Document 342 (Length: 367): Il faut déblayer, simplifier, supprimer. Le propre de l'homme, il me semble, c'est d'avoir rejeté au...
# ==========
#
#
# ==========
# Document 343 (Length: 727): On peut vivre ainsi ; rien n'empêche. Nous sommes admirablement faits pour pressentir ; si l'on tien...
# ==========
#
#
# ==========
# Document 344 (Length: 488): Un homme timide, dans une société, veut tout entendre, tout recueillir, tout interpréter. Et pour lu...
# ==========
#
#
# ==========
# Document 345 (Length: 686): Défrichement. J'ai connu une femme sensible qui souffrait de voir couper un tronc ou une branche. Ma...
# ==========
#
#
# ==========
# Document 346 (Length: 12): 25 août 1913...
# ==========
#
#
# ==========
# Document 347 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 348 (Length: 4): XXIV...
# ==========
#
#
# ==========
# Document 349 (Length: 12): Notre avenir...
# ==========
#
#
# ==========
# Document 350 (Length: 12): 28 août 1911...
# ==========
#
#
# ==========
# Document 351 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 352 (Length: 774): Tant que l'on n'a pas bien compris la liaison de toutes choses et l'enchaînement des causes et des e...
# ==========
#
#
# ==========
# Document 353 (Length: 866): L'idée qui sort de ces contes, c'est la prédestination que des théologiens mirent plus tard en doctr...
# ==========
#
#
# ==========
# Document 354 (Length: 564): D'où vient alors cette croyance à la destinée  ? De deux sources principalement. D'abord la peur nou...
# ==========
#
#
# ==========
# Document 355 (Length: 810): Il faut dire aussi que nos passions et nos vices ont bien cette puissance d'aller au même but par to...
# ==========
#
#
# ==========
# Document 356 (Length: 12): 28 août 1911...
# ==========
#
#
# ==========
# Document 357 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 358 (Length: 3): XXV...
# ==========
#
#
# ==========
# Document 359 (Length: 11): Prédictions...
# ==========
#
#
# ==========
# Document 360 (Length: 13): 14 avril 1908...
# ==========
#
#
# ==========
# Document 361 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 362 (Length: 649): Je connais quelqu'un qui a montré les lignes de sa main à un mage, afin de connaître sa destinée ; i...
# ==========
#
#
# ==========
# Document 363 (Length: 538): Je suppose que le mage croyait en lui-même ; car si le mage veut seulement rire, il annoncera des év...
# ==========
#
#
# ==========
# Document 364 (Length: 409): Mais si le mage est, à ses propres yeux, un vrai mage, alors il est bien capable de vous annoncer de...
# ==========
#
#
# ==========
# Document 365 (Length: 570): J'ai connu une jeune fille à qui un mage dit un jour, après avoir analysé les lignes de sa main : « ...
# ==========
#
#
# ==========
# Document 366 (Length: 570): Il arrive toutes sortes d'événements dans ce monde ; de là des rencontres qui ébranleront le plus fe...
# ==========
#
#
# ==========
# Document 367 (Length: 522): Pour mon compte, j'aime bien mieux ne pas penser à l'avenir, et ne prévoir que devant mes pieds. Non...
# ==========
#
#
# ==========
# Document 368 (Length: 13): 14 avril 1908...
# ==========
#
#
# ==========
# Document 369 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 370 (Length: 4): XXVI...
# ==========
#
#
# ==========
# Document 371 (Length: 7): Hercule...
# ==========
#
#
# ==========
# Document 372 (Length: 15): 7 novembre 1922...
# ==========
#
#
# ==========
# Document 373 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 374 (Length: 658): L'homme n'a de ressource que dans sa propre volonté ; idée aussi ancienne que les religions, les pro...
# ==========
#
#
# ==========
# Document 375 (Length: 710): J'aime un garçon qui réfléchit en surmontant, et qui, au tournant mal pris, dit d'abord : « C'est ma...
# ==========
#
#
# ==========
# Document 376 (Length: 674): Il y a deux expériences, l'une qui alourdit et l'autre qui allège. Comme il y a le chasseur gai et l...
# ==========
#
#
# ==========
# Document 377 (Length: 1245): Tout est contre nous ; mais disons mieux, tout est indifférent et sans égards ; la face de la terre ...
# ==========
#
#
# ==========
# Document 378 (Length: 15): 7 novembre 1922...
# ==========
#
#
# ==========
# Document 379 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 380 (Length: 5): XXVII...
# ==========
#
#
# ==========
# Document 381 (Length: 7): Vouloir...
# ==========
#
#
# ==========
# Document 382 (Length: 10): 9 mai 1909...
# ==========
#
#
# ==========
# Document 383 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 384 (Length: 435): « Les feuilles poussent. Bientôt, la galéruque, qui est une petite chenille verte, s'installera sur ...
# ==========
#
#
# ==========
# Document 385 (Length: 278): Ainsi gémissait un ami des arbres, comme nous nous promenions dans son parc. Il me montrait des orme...
# ==========
#
#
# ==========
# Document 386 (Length: 109): « Qu'est-ce qu'un millier de chenilles  ? répondit-il. Il y en a des millions. J'aime mieux n'y pas ...
# ==========
#
#
# ==========
# Document 387 (Length: 260): « Mais, lui dis-je, vous avez de l'argent. Avec de l'argent on achète des journées de travail. Dix o...
# ==========
#
#
# ==========
# Document 388 (Length: 168): « J'en ai trop, dit-il ; et j'ai trop peu d'ouvriers. Comment atteindront-ils les hautes branches  ?...
# ==========
#
#
# ==========
# Document 389 (Length: 217): « Deux, lui dis-je, c'est déjà quelque chose. Ils s'occuperont des hautes branches. D'autres moins h...
# ==========
#
#
# ==========
# Document 390 (Length: 146): « Le courage me manque, dit-il enfin. Je sais ce que je ferai. Je m'en irai pendant quelque temps, p...
# ==========
#
#
# ==========
# Document 391 (Length: 1409): « O puissance de l'imagination, lui répondis-je. Vous voilà en déroute avant d'avoir combattu. Ne re...
# ==========
#
#
# ==========
# Document 392 (Length: 10): 9 mai 1909...
# ==========
#
#
# ==========
# Document 393 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 394 (Length: 6): XXVIII...
# ==========
#
#
# ==========
# Document 395 (Length: 22): Chacun a ce qu'il veut...
# ==========
#
#
# ==========
# Document 396 (Length: 17): 21 septembre 1924...
# ==========
#
#
# ==========
# Document 397 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 398 (Length: 2150): Chacun a ce qu'il veut. La jeunesse se trompe là-dessus parce qu'elle ne sait bien que désirer et at...
# ==========
#
#
# ==========
# Document 399 (Length: 1764): Je reviens à dire que tous ceux qui veulent s'enrichir y arrivent. Cela scandalise tous ceux qui ont...
# ==========
#
#
# ==========
# Document 400 (Length: 17): 21 septembre 1924...
# ==========
#
#
# ==========
# Document 401 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 402 (Length: 4): XXIX...
# ==========
#
#
# ==========
# Document 403 (Length: 14): De la destinée...
# ==========
#
#
# ==========
# Document 404 (Length: 14): 3 octobre 1923...
# ==========
#
#
# ==========
# Document 405 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 406 (Length: 1310): « La Destinée, disait Voltaire, nous mène et se moque de nous. » Ce mot m'étonne de cet homme-là qui...
# ==========
#
#
# ==========
# Document 407 (Length: 1262): « Ce que jeunesse désire, vieillesse l'a en abondance. » C'est Goethe qui cite ce proverbe au commen...
# ==========
#
#
# ==========
# Document 408 (Length: 1147): Je vois des gens, qui, avec assez de moyens, ne sont arrivés qu'à une maigre et petite place. Mais q...
# ==========
#
#
# ==========
# Document 409 (Length: 14): 3 octobre 1923...
# ==========
#
#
# ==========
# Document 410 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 411 (Length: 3): XXX...
# ==========
#
#
# ==========
# Document 412 (Length: 17): Ne pas désespérer...
# ==========
#
#
# ==========
# Document 413 (Length: 12): 24 août 1912...
# ==========
#
#
# ==========
# Document 414 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 415 (Length: 593): Cette méthode de police qui consiste à guérir un ivrogne par le serment, porte la marque de l'action...
# ==========
#
#
# ==========
# Document 416 (Length: 1293): Dans le cas de l'ivrogne j'en vois bien la raison ; c'est l'usage ici qui fait le besoin ; car boire...
# ==========
#
#
# ==========
# Document 417 (Length: 729): Aux approches d'un déménagement vous dites adieu à ces murs que vous allez quitter ; votre mobilier ...
# ==========
#
#
# ==========
# Document 418 (Length: 582): Mon grand-père, vers ses soixante-dix ans, prit le dégoût des aliments solides, et vécut de lait pen...
# ==========
#
#
# ==========
# Document 419 (Length: 12): 24 août 1912...
# ==========
#
#
# ==========
# Document 420 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 421 (Length: 4): XXXI...
# ==========
#
#
# ==========
# Document 422 (Length: 22): Dans la grande prairie...
# ==========
#
#
# ==========
# Document 423 (Length: 11): 5 juin 1909...
# ==========
#
#
# ==========
# Document 424 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 425 (Length: 412): Platon a des contes de nourrice, qui ressemblent, en somme, à tous les contes de nourrice, mais qui,...
# ==========
#
#
# ==========
# Document 426 (Length: 808): Voici quelle était l'épreuve la plus redoutable. Les âmes, ou ombres, ou comme on voudra, sont condu...
# ==========
#
#
# ==========
# Document 427 (Length: 970): Voilà une singulière épreuve et une étrange punition, qui est pourtant plus redoutable qu'elle n'en ...
# ==========
#
#
# ==========
# Document 428 (Length: 1141): Mais les autres, qui ont galopé toute leur vie après leur désir, se régalant de ce qui leur semblait...
# ==========
#
#
# ==========
# Document 429 (Length: 11): 5 juin 1909...
# ==========
#
#
# ==========
# Document 430 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 431 (Length: 5): XXXII...
# ==========
#
#
# ==========
# Document 432 (Length: 21): Passions de voisinage...
# ==========
#
#
# ==========
# Document 433 (Length: 16): 27 décembre 1910...
# ==========
#
#
# ==========
# Document 434 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 435 (Length: 680): « Comme on vit mal, dit l'un, avec ceux que l'on connaît trop. On gémit sur soi-même sans retenue, e...
# ==========
#
#
# ==========
# Document 436 (Length: 1053): « Comme on vit mal, dit l'autre, avec ceux qu 1 on ne connaît pas du tout. Il y a des mineurs sous l...
# ==========
#
#
# ==========
# Document 437 (Length: 1370): « Comme on vit bien, dit un troisième, avec ceux qu'on ne connaît pas trop. Chacun retient ses parol...
# ==========
#
#
# ==========
# Document 438 (Length: 16): 27 décembre 1910...
# ==========
#
#
# ==========
# Document 439 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 440 (Length: 6): XXXIII...
# ==========
#
#
# ==========
# Document 441 (Length: 10): En famille...
# ==========
#
#
# ==========
# Document 442 (Length: 15): 12 juillet 1907...
# ==========
#
#
# ==========
# Document 443 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 444 (Length: 508): Il y a deux espèces d'hommes, ceux qui s'habituent au bruit et ceux qui essaient de faire taire les ...
# ==========
#
#
# ==========
# Document 445 (Length: 227): Ces deux espèces de gens fuient leurs contraires et cherchent leurs semblables par le monde. C'est p...
# ==========
#
#
# ==========
# Document 446 (Length: 1199): Il y a des familles où il est tacitement convenu que ce qui déplaît à l'un est interdit à tous les a...
# ==========
#
#
# ==========
# Document 447 (Length: 216): Il y a aussi d'autres familles où la fantaisie de chacun est chose sacrée, chose aimée, et où nul ne...
# ==========
#
#
# ==========
# Document 448 (Length: 15): 12 juillet 1907...
# ==========
#
#
# ==========
# Document 449 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 450 (Length: 5): XXXIV...
# ==========
#
#
# ==========
# Document 451 (Length: 11): Sollicitude...
# ==========
#
#
# ==========
# Document 452 (Length: 11): 30 mai 1907...
# ==========
#
#
# ==========
# Document 453 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 454 (Length: 605): Tout le monde connaît la fameuse scène où tous, à force de dire à Basile « vous êtes pâle à faire pe...
# ==========
#
#
# ==========
# Document 455 (Length: 437): Je plains l'homme sensible et un peu poltron qui est aimé, choyé, couvé, soigné de cette manière-là....
# ==========
#
#
# ==========
# Document 456 (Length: 447): Dès que l'on a un souci on perd le sommeil. Voilà donc notre malade imaginaire qui passe des nuits à...
# ==========
#
#
# ==========
# Document 457 (Length: 478): Le remède ? Fuir sa famille. Aller vivre au milieu d'indifférents, qui vous demanderont d'un air dis...
# ==========
#
#
# ==========
# Document 458 (Length: 11): 30 mai 1907...
# ==========
#
#
# ==========
# Document 459 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 460 (Length: 4): XXXV...
# ==========
#
#
# ==========
# Document 461 (Length: 17): La paix du ménage...
# ==========
#
#
# ==========
# Document 462 (Length: 15): 14 octobre 1913...
# ==========
#
#
# ==========
# Document 463 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 464 (Length: 396): Je reviens à ce terrible Poil de Carotte de Jules Renard. Ce livre est sans indulgence et il est bon...
# ==========
#
#
# ==========
# Document 465 (Length: 493): Dans la famille, et surtout si les cœurs sont tout à fait dévoués, personne ne se gêne, personne ne ...
# ==========
#
#
# ==========
# Document 466 (Length: 992): Un des effets de l'amour partagé, c'est que la mauvaise humeur y est échangée naïvement. Le sage y v...
# ==========
#
#
# ==========
# Document 467 (Length: 756): Tout naïvement chacun dit d'un être grognon ou hargneux qu'il connaît bien : « C'est son caractère. ...
# ==========
#
#
# ==========
# Document 468 (Length: 431): L'ordre familial c'est comme l'ordre du droit ; il ne se fait point tout seul ; il se fait et se con...
# ==========
#
#
# ==========
# Document 469 (Length: 15): 14 octobre 1913...
# ==========
#
#
# ==========
# Document 470 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 471 (Length: 5): XXXVI...
# ==========
#
#
# ==========
# Document 472 (Length: 16): De la vie privée...
# ==========
#
#
# ==========
# Document 473 (Length: 17): 10 septembre 1913...
# ==========
#
#
# ==========
# Document 474 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# ...
# ==========
#
#
# ==========
# Document 845 (Length: 8): Une cure...
# ==========
#
#
# ==========
# Document 846 (Length: 17): 24 septembre 1911...
# ==========
#
#
# ==========
# Document 847 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 848 (Length: 750): Après qu'ils eurent raconté leurs bains, leurs douches et leurs régimes : « Moi, dit l'autre, je fai...
# ==========
#
#
# ==========
# Document 849 (Length: 656): « Il y a, dit encore l'autre, des gens ennuyeux qui se réunissent pour récriminer et geindre ; on le...
# ==========
#
#
# ==========
# Document 850 (Length: 1068): « Les choses, dit encore l'autre, sont souvent bonnes aussi, je veux dire mauvaises, autant qu'il fa...
# ==========
#
#
# ==========
# Document 851 (Length: 17): 24 septembre 1911...
# ==========
#
#
# ==========
# Document 852 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 853 (Length: 4): LXXV...
# ==========
#
#
# ==========
# Document 854 (Length: 19): Hygiène de l'esprit...
# ==========
#
#
# ==========
# Document 855 (Length: 14): 9 octobre 1909...
# ==========
#
#
# ==========
# Document 856 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 857 (Length: 608): Je lisais hier un article sur une certaine espèce de fous à opinions, qui, à force de voir les chose...
# ==========
#
#
# ==========
# Document 858 (Length: 759): Il est sûr que chacun de nous a des pensées de fou autant qu'on voudra, comme rêves ou associations ...
# ==========
#
#
# ==========
# Document 859 (Length: 676): Je ne sais si ceux qui instruisent les enfants et les hommes ont assez réfléchi là-dessus. A les ent...
# ==========
#
#
# ==========
# Document 860 (Length: 1402): Qu'on dénoue les esprits, au contraire. Je donnerais comme règle d'hygiène : « N'aie jamais deux foi...
# ==========
#
#
# ==========
# Document 861 (Length: 14): 9 octobre 1909...
# ==========
#
#
# ==========
# Document 862 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 863 (Length: 5): LXXVI...
# ==========
#
#
# ==========
# Document 864 (Length: 15): L'hymne au lait...
# ==========
#
#
# ==========
# Document 865 (Length: 15): 21 janvier 1924...
# ==========
#
#
# ==========
# Document 866 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 867 (Length: 934): Je trouve en Descartes cette idée que la passion de l'amour est bonne pour la santé, et la haine, au...
# ==========
#
#
# ==========
# Document 868 (Length: 1113): Il faut donc comprendre par les causes ; et je trouve aussi ces causes en Descartes. Car quel est, d...
# ==========
#
#
# ==========
# Document 869 (Length: 1068): On peut agrandir, on peut enfler cette idée admirable ; on ne la fatiguera point, on n'en trouvera p...
# ==========
#
#
# ==========
# Document 870 (Length: 15): 21 janvier 1924...
# ==========
#
#
# ==========
# Document 871 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 872 (Length: 6): LXXVII...
# ==========
#
#
# ==========
# Document 873 (Length: 6): Amitié...
# ==========
#
#
# ==========
# Document 874 (Length: 16): 27 décembre 1907...
# ==========
#
#
# ==========
# Document 875 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 876 (Length: 436): Il y a de merveilleuses joies dans l'amitié. On le comprend sans peine si l'on remarque que la joie ...
# ==========
#
#
# ==========
# Document 877 (Length: 661): La source de la joie est au-dedans, j'en conviens ; et rien n'est plus attristant que de voir des ge...
# ==========
#
#
# ==========
# Document 878 (Length: 356): Voici un paquet de branches sèches. Elles sont inertes en apparence comme la terre ; si vous les lai...
# ==========
#
#
# ==========
# Document 879 (Length: 684): C'est ainsi qu'il faut une espèce de mise en train pour éveiller la joie. Lorsque le petit enfant ri...
# ==========
#
#
# ==========
# Document 880 (Length: 16): 27 décembre 1907...
# ==========
#
#
# ==========
# Document 881 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 882 (Length: 7): LXXVIII...
# ==========
#
#
# ==========
# Document 883 (Length: 17): De l'irrésolution...
# ==========
#
#
# ==========
# Document 884 (Length: 12): 10 août 1924...
# ==========
#
#
# ==========
# Document 885 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 886 (Length: 1048): Descartes dit que l'irrésolution est le plus grand des maux. Il le dit plus d'une fois, il ne l'expl...
# ==========
#
#
# ==========
# Document 887 (Length: 944): On peut se demander de quoi souffre un homme amoureux qui ne dort point, ou bien l'ambitieux déçu. C...
# ==========
#
#
# ==========
# Document 888 (Length: 818): J'ai souvent pensé que la peur, qui est la passion nue, et la plus pénible, n'est autre chose que le...
# ==========
#
#
# ==========
# Document 889 (Length: 738): Descartes en ses pensées est tout de même. Hardi en ses pensées et toujours se mouvant par son décre...
# ==========
#
#
# ==========
# Document 890 (Length: 12): 10 août 1924...
# ==========
#
#
# ==========
# Document 891 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 892 (Length: 5): LXXIX...
# ==========
#
#
# ==========
# Document 893 (Length: 10): Cérémonies...
# ==========
#
#
# ==========
# Document 894 (Length: 17): 26 septembre 1923...
# ==========
#
#
# ==========
# Document 895 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 896 (Length: 1351): Si l'irrésolution est le pire des maux, on comprend que la cérémonie, la fonction, le costume, la mo...
# ==========
#
#
# ==========
# Document 897 (Length: 1283): La guerre a tout pour déplaire ; mais le raisonnement se trompe là ; c'est que les hommes y trouvent...
# ==========
#
#
# ==========
# Document 898 (Length: 893): On voudrait rire de la mode ; mais la mode est quelque chose de très sérieux. L'esprit se donne l'ai...
# ==========
#
#
# ==========
# Document 899 (Length: 17): 26 septembre 1923...
# ==========
#
#
# ==========
# Document 900 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 901 (Length: 4): LXXX...
# ==========
#
#
# ==========
# Document 902 (Length: 11): Bonne année...
# ==========
#
#
# ==========
# Document 903 (Length: 14): 2 janvier 1910...
# ==========
#
#
# ==========
# Document 904 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 905 (Length: 835): Tous ces cadeaux, en temps d'étrennes, arrivent à remuer plus de tristesses que de joies. Car person...
# ==========
#
#
# ==========
# Document 906 (Length: 2371): Venons au sérieux. Je vous souhaite la bonne humeur. Voilà ce qu'il faudrait offrir et recevoir. Voi...
# ==========
#
#
# ==========
# Document 907 (Length: 14): 2 janvier 1910...
# ==========
#
#
# ==========
# Document 908 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 909 (Length: 5): LXXXI...
# ==========
#
#
# ==========
# Document 910 (Length: 4): Vœux...
# ==========
#
#
# ==========
# Document 911 (Length: 16): 20 décembre 1926...
# ==========
#
#
# ==========
# Document 912 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 913 (Length: 775): Tous ces souhaits et tous ces vœux, floraison de janvier, ce ne sont que des signes ; soit. Mais les...
# ==========
#
#
# ==========
# Document 914 (Length: 1349): Chose digne de remarque, on se trouve plus fort contre une opinion appuyée de raisons, et en paroles...
# ==========
#
#
# ==========
# Document 915 (Length: 1188): J'en reviens à cette fête de la politesse, qui est une importante fête. Dans le temps où chacun rega...
# ==========
#
#
# ==========
# Document 916 (Length: 649): Ce jour de fête vous sera bon, que vous le vouliez ou non. Mais, si vous le voulez, si vous retourne...
# ==========
#
#
# ==========
# Document 917 (Length: 16): 20 décembre 1926...
# ==========
#
#
# ==========
# Document 918 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 919 (Length: 6): LXXXII...
# ==========
#
#
# ==========
# Document 920 (Length: 12): La politesse...
# ==========
#
#
# ==========
# Document 921 (Length: 14): 6 janvier 1922...
# ==========
#
#
# ==========
# Document 922 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 923 (Length: 609): La politesse s'apprend comme la danse. Celui qui ne sait pas danser croit que le difficile est de co...
# ==========
#
#
# ==========
# Document 924 (Length: 1211): J'ai remarqué souvent un son de voix qui est par lui-même impoli ; un maître de chant dirait que la ...
# ==========
#
#
# ==========
# Document 925 (Length: 1319): Un homme impoli est encore impoli quand il est seul ; trop de force dans le moindre mouvement. On se...
# ==========
#
#
# ==========
# Document 926 (Length: 14): 6 janvier 1922...
# ==========
#
#
# ==========
# Document 927 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 928 (Length: 7): LXXXIII...
# ==========
#
#
# ==========
# Document 929 (Length: 12): Savoir-vivre...
# ==========
#
#
# ==========
# Document 930 (Length: 12): 21 mars 1911...
# ==========
#
#
# ==========
# Document 931 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 932 (Length: 580): Il y a une politesse de courtisan, qui n'est pas belle. Mais aussi ce n'est point de la politesse. E...
# ==========
#
#
# ==========
# Document 933 (Length: 340): Un homme de premier mouvement, qui dit tout ce qui lui vient, qui s'abandonne au premier sentiment, ...
# ==========
#
#
# ==========
# Document 934 (Length: 603): Il est pénible de blesser quelqu'un sans l'avoir voulu, par un récit à l'étourdie ; l'homme poli est...
# ==========
#
#
# ==========
# Document 935 (Length: 504): Impolitesse est toujours maladresse. Il est méchant de faire sentir à quelqu'un l'âge qu'il a ; mais...
# ==========
#
#
# ==========
# Document 936 (Length: 1086): La politesse est donc une habitude et une aisance. L'impoli c'est celui qui fait autre chose que ce ...
# ==========
#
#
# ==========
# Document 937 (Length: 12): 21 mars 1911...
# ==========
#
#
# ==========
# Document 938 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 939 (Length: 6): LXXXIV...
# ==========
#
#
# ==========
# Document 940 (Length: 13): Faire plaisir...
# ==========
#
#
# ==========
# Document 941 (Length: 11): 8 mars 1911...
# ==========
#
#
# ==========
# Document 942 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 943 (Length: 1075): Je parlais d'un « art de vivre » qu'il faudrait enseigner. J'y mettrais cette règle : « faire plaisi...
# ==========
#
#
# ==========
# Document 944 (Length: 543): Il y a à louer presque dans tout ; car les vrais mobiles, nous les ignorons toujours, et il n'en coû...
# ==========
#
#
# ==========
# Document 945 (Length: 606): Il me revient ici un récit d'école maternelle. Un tout petit garnement, qui ne faisait jusque-là que...
# ==========
#
#
# ==========
# Document 946 (Length: 385): Mais ce sont des cas difficiles. Il y en a tant d'autres où l'on peut toujours, sans hésitation, sou...
# ==========
#
#
# ==========
# Document 947 (Length: 608): C'est ainsi que je concevrais la politesse ; ce n'est qu'une gymnastique contre les passions. Être p...
# ==========
#
#
# ==========
# Document 948 (Length: 11): 8 mars 1911...
# ==========
#
#
# ==========
# Document 949 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 950 (Length: 5): LXXXV...
# ==========
#
#
# ==========
# Document 951 (Length: 14): Platon médecin...
# ==========
#
#
# ==========
# Document 952 (Length: 14): 4 février 1922...
# ==========
#
#
# ==========
# Document 953 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 954 (Length: 1561): Gymnastique et musique étaient les deux grands moyens de Platon médecin. Gymnastique signifie travai...
# ==========
#
#
# ==========
# Document 955 (Length: 1498): Quelqu'un qui souffrait de la tête me disait ces jours-ci que les mouvements de mastication, pendant...
# ==========
#
#
# ==========
# Document 956 (Length: 14): 4 février 1922...
# ==========
#
#
# ==========
# Document 957 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 958 (Length: 6): LXXXVI...
# ==========
#
#
# ==========
# Document 959 (Length: 23): L'art de se bien porter...
# ==========
#
#
# ==========
# Document 960 (Length: 17): 28 septembre 1921...
# ==========
#
#
# ==========
# Document 961 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 962 (Length: 2330): L'égalité d'âme ne reçoit pas, en général, de récompenses extérieures ; mais elle est certainement f...
# ==========
#
#
# ==========
# Document 963 (Length: 1038): Ce n'est pas une faute d'être malade ; la discipline ne peut rien dire contre, ni l'honneur. Quel es...
# ==========
#
#
# ==========
# Document 964 (Length: 17): 28 septembre 1921...
# ==========
#
#
# ==========
# Document 965 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 966 (Length: 7): LXXXVII...
# ==========
#
#
# ==========
# Document 967 (Length: 9): Victoires...
# ==========
#
#
# ==========
# Document 968 (Length: 12): 18 mars 1911...
# ==========
#
#
# ==========
# Document 969 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 970 (Length: 645): Dès qu'un homme cherche le bonheur, il est condamné à ne pas le trouver, et il n'y a point de mystèr...
# ==========
#
#
# ==========
# Document 971 (Length: 1461): Les poètes expliquent souvent mal les choses ; et je le comprends bien ; ils ont tant de mal à ajust...
# ==========
#
#
# ==========
# Document 972 (Length: 1236): Mais il y a des bonheurs solitaires qui portent toujours les mêmes marques, action, travail, victoir...
# ==========
#
#
# ==========
# Document 973 (Length: 12): 18 mars 1911...
# ==========
#
#
# ==========
# Document 974 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 975 (Length: 8): LXXXVIII...
# ==========
#
#
# ==========
# Document 976 (Length: 6): Poètes...
# ==========
#
#
# ==========
# Document 977 (Length: 17): 12 septembre 1923...
# ==========
#
#
# ==========
# Document 978 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 979 (Length: 1863): C'est une belle amitié que celle de Goethe et de Schiller, que l'on voit dans leurs lettres. Chacun ...
# ==========
#
#
# ==========
# Document 980 (Length: 1558): Je suppose que le poète, et tout artiste, est averti, par le bonheur, de ce qu'il peut et ne peut pa...
# ==========
#
#
# ==========
# Document 981 (Length: 17): 12 septembre 1923...
# ==========
#
#
# ==========
# Document 982 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 983 (Length: 6): LXXXIX...
# ==========
#
#
# ==========
# Document 984 (Length: 17): Bonheur est vertu...
# ==========
#
#
# ==========
# Document 985 (Length: 15): 5 novembre 1922...
# ==========
#
#
# ==========
# Document 986 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 987 (Length: 835): Il y a un genre de bonheur qui ne tient pas plus à nous qu'un manteau. Ainsi le bonheur d'hériter ou...
# ==========
#
#
# ==========
# Document 988 (Length: 1343): Les sages d'autrefois cherchaient le bonheur ; non pas le bonheur du voisin, mais leur bonheur propr...
# ==========
#
#
# ==========
# Document 989 (Length: 958): M'est avis, donc, que le bonheur intime et propre n'est point contraire à la vertu, mais plutôt est ...
# ==========
#
#
# ==========
# Document 990 (Length: 15): 5 novembre 1922...
# ==========
#
#
# ==========
# Document 991 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 992 (Length: 2): XC...
# ==========
#
#
# ==========
# Document 993 (Length: 27): Que le bonheur est généreux...
# ==========
#
#
# ==========
# Document 994 (Length: 13): 10 avril 1923...
# ==========
#
#
# ==========
# Document 995 (Length: 30): Retour à la table des matières...
# ==========
#
#
# ==========
# Document 996 (Length: 1265): Il faut vouloir être heureux et y mettre du sien. Si l'on reste dans la position du spectateur impar...
# ==========
#
#
# ==========
# Document 997 (Length: 720): Chacun a observé quelque tyran domestique ; et l'on voudrait penser, par une vue trop simple, que l'...
# ==========
#
#
# ==========
# Document 998 (Length: 1291): C'est ce que nous apprend la politesse, qui est un bonheur d'apparence, aussitôt ressenti par la réa...
# ==========
#
#
# ==========
# Document 999 (Length: 13): 10 avril 1923...
# ==========
#
#
# ==========
# Document 1000 (Length: 28): Propos sur le bonheur (1928)...
# ==========
#
#
# ==========
# Document 1001 (Length: 3): XCI...
# ==========

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

from dotenv import load_dotenv
import os

# 最初に環境変数を読み込む
load_dotenv()


class VectorDB:
    def __init__(self, db_name):
        self.embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
        self.db = Chroma(persist_directory=db_name, embedding_function=self.embeddings)

    def add_documents(self, documents):
        self.db.add_documents(documents)

    def similarity_search(self, query, **kwargs):
        return self.db.similarity_search(query, **kwargs)
       
    def as_retriever(self, **kwargs):
        return self.db.as_retriever(**kwargs)

# %%
vector_db = VectorDB(db_name='vector_db')
vector_db.add_documents(documents)

question = 'Que faire quand on ne se sent pas bien ?'
results = vector_db.similarity_search(question)
display([result.page_content for result in results])
# Out:
# ERROR: Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ERROR: Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ["Le remède\xa0? Fuir sa famille. Aller vivre au milieu d'indifférents, qui vous demanderont d'un air distrait\xa0: «\xa0Comment vous portez-vous\xa0?», mais s'enfuiront si vous répondez sérieusement\xa0; de gens qui n'écouteront pas vos plaintes et ne poseront pas sur vous ce regard chargé de tendre sollicitude qui vous étranglait l'estomac. Dans ces conditions, si vous ne tombez pas tout de suite dans le désespoir, vous guérirez. Morale\xa0: ne dites jamais à quelqu'un qu'il a mauvaise mine.",
#  "Le remède\xa0? Fuir sa famille. Aller vivre au milieu d'indifférents, qui vous demanderont d'un air distrait\xa0: «\xa0Comment vous portez-vous\xa0?», mais s'enfuiront si vous répondez sérieusement\xa0; de gens qui n'écouteront pas vos plaintes et ne poseront pas sur vous ce regard chargé de tendre sollicitude qui vous étranglait l'estomac. Dans ces conditions, si vous ne tombez pas tout de suite dans le désespoir, vous guérirez. Morale\xa0: ne dites jamais à quelqu'un qu'il a mauvaise mine.",
#  "Le remède\xa0? Fuir sa famille. Aller vivre au milieu d'indifférents, qui vous demanderont d'un air distrait\xa0: «\xa0Comment vous portez-vous\xa0?», mais s'enfuiront si vous répondez sérieusement\xa0; de gens qui n'écouteront pas vos plaintes et ne poseront pas sur vous ce regard chargé de tendre sollicitude qui vous étranglait l'estomac. Dans ces conditions, si vous ne tombez pas tout de suite dans le désespoir, vous guérirez. Morale\xa0: ne dites jamais à quelqu'un qu'il a mauvaise mine.",
#  "Un amoureux que sa belle a renvoyé ne voudrait pas penser à autre chose\xa0; mais il reprend les bonheurs passés et les perfections de l'infidèle, et ses perfidies, et ses injustices. Il se fouette lui-même de tout son cœur. Il devrait, s'il ne peut penser à quelque autre chose, considérer son malheur autrement\xa0; se dire que c'est une petite sotte qui n'est plus déjà de première fraîcheur\xa0; imaginer la vie qu'il aurait eue avec cette femme devenue vieille\xa0; peser scrupuleusement les joies passées\xa0; faire la part de son propre enthousiasme\xa0; faire revivre ces minutes discordantes sur lesquelles on passe quand on est heureux, mais qui, dans la tristesse, servent alors de consolation. Finalement arrêter son attention sur quelque trait physique, œil, nez, bouche, main, pied, son de voix qui ne plaît pas\xa0; il y en a toujours\xa0; j'avoue que c'est là un remède héroïque. Il est plus aisé de se jeter dans un travail compliqué ou dans une action difficile. Mais de toute façon, il faut s'appliquer à se consoler, au lieu de se jeter au malheur comme au gouffre. Et ceux qui s'y appliqueront de bonne foi seront bien plus vite consolés qu'ils ne pensent."]

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

def create_simple_rag_chain(vector_db):
    prompt = ChatPromptTemplate.from_template('''
    質問: {question}

    情報源: """{context}
    """
    ''')

    llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.1)
    retriever = vector_db.as_retriever()

    chain = {
        'question': RunnablePassthrough(),
        'context': retriever
    } | prompt | llm | StrOutputParser()
    return chain

# %%
def create_multilingual_rag_chain(vector_db):
    # 質問翻訳用のチェーン
    translation_prompt = ChatPromptTemplate.from_template('''
    以下の日本語の質問をフランス語に翻訳してください。翻訳結果のみを返してください。
    
    質問: {question}
    ''')
    
    # 回答生成用のプロンプト
    answer_prompt = ChatPromptTemplate.from_template('''
    以下のフランス語の情報源を参考にして、日本語で質問に答えてください。
    
    元の質問（日本語）: {original_question}
    
    情報源（フランス語）:
    {context}
    
    回答は日本語で、情報源の内容を正確に反映してください。
    ''')

    llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.1)
    retriever = vector_db.as_retriever(search_kwargs={"k": 3})

    # 質問を翻訳してから検索
    chain = {
        'original_question': RunnablePassthrough(),
        'translated_question': translation_prompt | llm | StrOutputParser(),
    } | {
        'original_question': lambda x: x['original_question'],
        'context': lambda x: retriever.invoke(x['translated_question'])
    } | answer_prompt | llm | StrOutputParser()
    
    return chain

# %%
def create_multilingual_rag_chain(vector_db):
    # 質問翻訳用のチェーン
    translation_prompt = ChatPromptTemplate.from_template('''
    以下の日本語の質問をフランス語に翻訳してください。翻訳結果のみを返してください。
    
    質問: {question}
    ''')
    
    # 回答生成用のプロンプト
    answer_prompt = ChatPromptTemplate.from_template('''
    以下のフランス語の情報源を参考にして、日本語で質問に答えてください。
    
    元の質問（日本語）: {original_question}
    
    情報源（フランス語）:
    {context}
    
    回答は日本語で、情報源の内容を正確に反映してください。
    ''')

    llm = ChatOpenAI(model='gpt-4o-mini', temperature=0.1)
    retriever = vector_db.as_retriever(search_kwargs={"k": 3})

    # シンプルな修正版
    chain = (
        {"question": RunnablePassthrough()}
        | RunnablePassthrough.assign(
            translated_question=translation_prompt | llm | StrOutputParser()
        )
        | RunnablePassthrough.assign(
            original_question=lambda x: x["question"],
            context=lambda x: retriever.invoke(x["translated_question"])
        )
        | answer_prompt 
        | llm 
        | StrOutputParser()
    )
    
    return chain

# %%
import langchain
langchain.verbose = False
langchain.debug = False
langchain.llm_cache = False

question = '気分をよくするためにはどうすればいいですか？'
chain = create_multilingual_rag_chain(vector_db)
result = chain.invoke(question)
print(result)
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 気分をよくするためには、家族から離れて無関心な人々の中で生活することが一つの方法です。無関心な人々は、あなたに「元気ですか？」と気軽に尋ねるかもしれませんが、真剣に答えると逃げてしまいます。彼らはあなたの不満を聞かず、あなたに対して過度な関心を持たないため、気持ちが楽になるかもしれません。このような環境で、すぐに絶望に陥らなければ、気分は改善されるでしょう。重要な教訓は、誰かに「あなたは元気がない」と言わないことです。

# %%
import langchain
langchain.verbose = False
langchain.debug = False
langchain.llm_cache = False

question = 'Que faire quand on ne se sent pas bien ?'
chain = create_simple_rag_chain(vector_db)
result = chain.invoke(question)
print(result)
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Quand on ne se sent pas bien, il existe plusieurs approches que l'on peut envisager pour améliorer son état. Voici quelques suggestions :
#
# 1. **Éloignement des sources de stress** : Parfois, s'éloigner de son environnement habituel, comme sa famille ou des personnes qui suscitent des émotions négatives, peut aider. Cela permet de se retrouver dans un cadre où l'on se sent moins jugé et plus libre d'exprimer ses sentiments sans crainte de réaction.
#
# 2. **Prendre du temps pour soi** : S'accorder des moments de solitude ou de réflexion peut être bénéfique. Cela peut inclure des activités relaxantes comme la lecture, la méditation ou simplement se promener dans la nature.
#
# 3. **Parler à quelqu'un** : Si vous vous sentez à l'aise, partager vos sentiments avec un ami ou un professionnel peut apporter un soulagement. Parfois, le simple fait de verbaliser ses pensées aide à les clarifier et à les atténuer.
#
# 4. **Se concentrer sur des activités positives** : S'engager dans des activités qui vous apportent de la joie ou qui vous intéressent peut détourner votre esprit des pensées négatives. Cela peut être un hobby, du sport ou même des projets créatifs.
#
# 5. **Réévaluation des pensées** : Essayer de changer votre perspective sur la situation qui vous affecte. Par exemple, si vous ressentez de la tristesse à cause d'une rupture, réfléchir aux aspects positifs de votre vie ou aux leçons apprises peut aider à atténuer la douleur.
#
# 6. **Prendre soin de soi** : Assurez-vous de bien manger, de dormir suffisamment et de faire de l'exercice. Ces éléments fondamentaux ont un impact significatif sur notre bien-être mental et physique.
#
# 7. **Chercher de l'aide professionnelle** : Si les sentiments de mal-être persistent, il peut être utile de consulter un professionnel de la santé mentale qui pourra vous offrir un soutien adapté.
#
# En résumé, il est important de trouver des moyens de se consoler et de se distraire des pensées négatives, tout en cherchant des solutions constructives pour améliorer son état.
